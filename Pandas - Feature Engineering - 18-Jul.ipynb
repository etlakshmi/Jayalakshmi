# %%
import numpy as np
import pandas as pd

# %%
#Load the Cars dataset
df=pd.read_csv("Cars.csv")

# %%
#Find the first five rows
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
#List out the last ten instances 
df.tail(10)
# Out:
#      symboling normalized-losses   make fuel-type body-style drive-wheels  \
# 195         -1                74  volvo       gas      wagon          rwd
# 196         -2               103  volvo       gas      sedan          rwd
# 197         -1                74  volvo       gas      wagon          rwd
# 198         -2               103  volvo       gas      sedan          rwd
# 199         -1                74  volvo       gas      wagon          rwd
# 200         -1                95  volvo       gas      sedan          rwd
# 201         -1                95  volvo       gas      sedan          rwd
# 202         -1                95  volvo       gas      sedan          rwd
# 203         -1                95  volvo    diesel      sedan          rwd
# 204         -1                95  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 195           front   67.2    57.5         ohc          141        114
# ...

# %%
#Take descriptive measurements
df.describe()
# Out:
#         symboling       width      height  engine-size    city-mpg  \
# count  205.000000  205.000000  205.000000   205.000000  205.000000
# mean     0.834146   65.907805   53.724878   126.907317   25.219512
# std      1.245307    2.145204    2.443522    41.642693    6.542142
# min     -2.000000   60.300000   47.800000    61.000000   13.000000
# 25%      0.000000   64.100000   52.000000    97.000000   19.000000
# 50%      1.000000   65.500000   54.100000   120.000000   24.000000
# 75%      2.000000   66.900000   55.500000   141.000000   30.000000
# max      3.000000   72.300000   59.800000   326.000000   49.000000
#
#        highway-mpg         price
# count   205.000000    205.000000
# mean     30.751220  13227.478049
# std       6.886443   7902.651615
# min      16.000000   5118.000000
# 25%      25.000000   7788.000000
# 50%      30.000000  10345.000000
# 75%      34.000000  16500.000000
# max      54.000000  45400.000000

# %%
#Show information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
#Calculate the average price of Honda cars
df[df["make"]=="honda"]["price"].mean()
# Out:
# 8184.692307692308

# %%
#Caclucate the average price of all the cars
df.groupby("make")["price"].mean()
# Out:
# make
# alfa-romero      15498.333333
# audi             17022.142857
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu            12708.250000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          27520.400000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64

# %%
#Analyze which car is costly based on the fuel type
df.groupby("fuel-type")["price"].mean()
# Out:
# fuel-type
# diesel    15838.150000
# gas       12945.243243
# Name: price, dtype: float64

# %%
#To display unique values in a dataset
df["fuel-type"].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
#To display count of unique dataset
df["fuel-type"].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
#Sort the data based on price
df.sort_values("price")
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 138          2                83         subaru       gas    hatchback
# 18           2               121      chevrolet       gas    hatchback
# 50           1               104          mazda       gas    hatchback
# 150          1                87         toyota       gas    hatchback
# 76           2               161     mitsubishi       gas    hatchback
# ..         ...               ...            ...       ...          ...
# 17           0                 ?            bmw       gas        sedan
# 128          3                 ?        porsche       gas  convertible
# 73           0                 ?  mercedes-benz       gas        sedan
# 16           0                 ?            bmw       gas        sedan
# 74           1                 ?  mercedes-benz       gas      hardtop
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
#Calculate the mean value of price of cars based on the fuel-type
df.groupby("fuel-type")["price"].mean()
# Out:
# fuel-type
# diesel    15838.150000
# gas       12945.243243
# Name: price, dtype: float64

# %%
#Drop a feature
df.drop(103,inplace=True)

# %%
df.drop([23,24,25,26,27],inplace=True)

# %%
df.drop(23)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.drop(23)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
# ...

# %%
print(df)

# %%
df.drop("engine-location",axis=1,inplace=True)

# %%
df.head()

# %%
df.drop(["city-mpg","highway-mpg","normalized-losses"],axis=1)
